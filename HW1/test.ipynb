# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]

y = [99,86,87,88,111,86,103,87,94,78,77,85,86]

print(len(x))
print(len(y))
# Out:
# 13
# 13

# %%
import pandas as pd
df = pd.DataFrame([['Jay','M',18],['Jennifer','F',17],
                   ['Preity','F',19],['Neil','M',17]], 
                  columns = ['Name','Gender','Age'])
df1 = df.iloc[:,:2]
df2 = df.iloc[:,2:]
print(len(df1))
print(df2)
# Out:
# 4
#    Age
# 0   18
# 1   17
# 2   19
# 3   17

# %%
data = pd.read_csv("test.csv")
print(data)
# Out:
#             x         y
# 0   -3.141593 -0.228450
# 1   -3.135303 -0.390851
# 2   -3.129014 -0.466575
# 3   -3.122724  0.253540
# 4   -3.116435 -0.059069
# ..        ...       ...
# 995  3.116435 -0.189928
# 996  3.122724 -0.477250
# 997  3.129014  0.322295
# 998  3.135303  0.136544
# 999  3.141593 -0.123016
#
# [1000 rows x 2 columns]

# %%
data.shape
# Out:
# (1000, 2)

# %%
plt.scatter(data.iloc[:,0],data.iloc[:,1])
plt.title('Main')
plt.show()

# %%
import matplotlib.pyplot as plt
data.plot(x='x', y='y', style='o')
plt.title('Hours vs Percentage')
plt.xlabel('Hours Studied')
plt.ylabel('Percentage Score')
plt.show()

# %%
X = data.iloc[:, :-1]
y = data.iloc[:, 1]
print('x is',x)
print('Y is ',y)
# Out:
# x is [5, 7, 8, 7, 2, 17, 2, 9, 4, 11, 12, 9, 6]
# Y is  0     -0.228450
# 1     -0.390851
# 2     -0.466575
# 3      0.253540
# 4     -0.059069
#          ...
# 995   -0.189928
# 996   -0.477250
# 997    0.322295
# 998    0.136544
# 999   -0.123016
# Name: y, Length: 1000, dtype: float64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
def split_train_test(data,ratio=0.2):
    shuffled_index =np.random.permutation(len(data))
    test_set_size = int(len(data)*ratio)
    test_index =  shuffled_index[:test_set_size]
    train_index = shuffled_index[test_set_size:]
    return data.iloc[train_index],data.iloc[test_index]

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size = 0.2, random_state = 42)
for train_index,test_index in split.split(data.iloc[:,1:],data.iloc[:,1:]):
    new_train_set = data.iloc[train_index]
    new_test_set = data.iloc[test_index]

print(len(new_train_set))
print(len(new_test_set))

# %%
from sklearn.model_selection import LeaveOneOut
x = data.iloc[:,0]
y = data.iloc[:]
loo = LeaveOneOut()
loo.get_n_splits(X)

print(loo)
LeaveOneOut()
for train_index, test_index in loo.split(X):
         print("TRAIN:", train_index, "TEST:", test_index)
         X_train, X_test = X[train_index], X[test_index]
         y_train, y_test = y[train_index], y[test_index]
         print(X_train, X_test, y_train, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14524/1734058560.py in <module>
#       1 from sklearn.model_selection import LeaveOneOut
# ----> 2 x = data.iloc[:,0]
#       3 y = data.iloc[:]
#       4 loo = LeaveOneOut()
#       5 loo.get_n_splits(X)
#
# NameError: name 'data' is not defined
